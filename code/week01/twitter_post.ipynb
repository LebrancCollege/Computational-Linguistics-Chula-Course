# %%
import pandas as pd

# %%
twitter_data = pd.read_csv("../../data/csv/twitter-post.csv")
print(twitter_data)
# Out:
#                       id      user_posted                     name  \
# 0    1795704262074507432       KhadimHaqq              Khadim Haqq
# 1    1720922514690375706      nida_journo            Nida' Ibrahim
# 2    1727113960967885140         Morgayze  Morgayze - Original 𐚁 🍉
# 3    1800863719293083764          zyyluvs                    izy⁷🐳
# 4    1799608510902370599     GaryWKinsman             Gary Kinsman
# ..                   ...              ...                      ...
# 995  1725541143096537253         NoeMore5                 Noe More
# 996  1732064512126128556  freedspch_GenXZ        FREEDOM_OF_SPEECH
# 997  1798798154286158167      FabFourLoko      Dree | NOW AND THEN
# 998  1809622341229416936    SusanRinkunas           Susan Rinkunas
# 999  1783018667992592863  marigoldglitter               🍉 Nevena🔻🪐
#
#                                            description  \
# 0    What is he gonna do about it though? Jumped on...
# ...
